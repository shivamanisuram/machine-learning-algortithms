# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamanisuram/machine-learning-algortithms/blob/main/PRINCIPAL_COMPONENET_ANALYSIS(PCA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
x1=np.array([1,2,3,4,5,6])
x2=np.array([7.5,11,16,18,20,26])

# %%
plt.scatter(x1,x2)
plt.show()

# %%
x=np.c_[x1,x2]

# %%
x
# Out:
# array([[ 1. ,  7.5],
#        [ 2. , 11. ],
#        [ 3. , 16. ],
#        [ 4. , 18. ],
#        [ 5. , 20. ],
#        [ 6. , 26. ]])

# %%
pca=PCA(n_components=1)
x_transformed=pca.fit_transform(x)

# %%
x_transformed
# Out:
# array([[-9.26049952],
#        [-5.62047228],
#        [-0.53656217],
#        [ 1.65958219],
#        [ 3.85572654],
#        [ 9.90222524]])

# %%
pca.components_
# Out:
# array([[0.27096719, 0.96258858]])

# %%
x_approx=pca.inverse_transform(x_transformed)

# %%
plt.scatter(x_approx[:,0],x_approx[:,1],color='red')
plt.show()
